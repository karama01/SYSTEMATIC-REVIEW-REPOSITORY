# %% [markdown]
# Parsing Medline file

# %%
from Bio import Medline
import pandas as pd

# %%
from Bio import Medline

# Open the output CSV file
with open("table1.csv", "w") as file:
    # Write the header line for clarity
    file.write("Journal\tTitle\tAuthors\tYear\tAbstract\tPaper type\n")

    # Open the MEDLINE file
    with open("/content/pmc_result.medline") as handle:
        records = Medline.parse(handle)

        # Iterate through each record in the MEDLINE file
        for record in records:
            # Use .get() to handle missing fields
            title = record.get("TI", "No title")
            journal = record.get("JT", "No journal")
            authors = "; ".join(record.get("FAU", ["No authors"]))
            year = record.get("DP", "N/A").split(" ")[0]  # Get year, or N/A if missing
            abstract = record.get("AB", "No abstract")
            paper_type = record.get("PT", "No paper type")

            # Write each record's details into the CSV file
            file.write(f"{journal}\t{title}\t{authors}\t{year}\t{abstract}\t{paper_type}\n")

# %%
df = pd.read_csv("/content/table1.csv", sep="\t")
df.columns = ["Journal", "Title", "Authors", "Year", "Abstract", "Paper_type"]
df
# Out:
#                                                 Journal  \
# 0                         Clinical Microbiology Reviews
# 1            BMC Complementary and Alternative Medicine
# 2     Molecules : A Journal of Synthetic Chemistry a...
# 3              BMC Complementary Medicine and Therapies
# 4                                               Viruses
# ...                                                 ...
# 8246                          ACS Chemical Neuroscience
# 8247                         Acta Pharmacologica Sinica
# 8248                                           PLoS ONE
# 8249                                          Molecules
# 8250                                 Scientific Reports
#
#                                                   Title  \
# 0     Natural-Product-Based Solutions for Tropical I...
# 1     Antibacterial activities, proposed mode of act...
# 2     Anti-Trypanosomatid Elemanolide Sesquiterpene ...
# 3     Phytochemical analysis and versatile in vitro ...
# 4     Antiviral and Cytotoxic Activity of Different ...
# ...                                                 ...
# 8246  Tanshinones Inhibit Amyloid Aggregation by Amy...
# 8247  Salvianolic acid B ameliorates depressive-like...
# 8248  Cardiac Microvascular Barrier Function Mediate...
# 8249  Production of Salvianolic Acid B in Roots of S...
# 8250  Network pharmacology and molecular docking stu...
#
#                                                 Authors    Year  \
# 0     Adegboye, Oyelola; Field, Matt A.; Kupz, Andre...     NaN
# 1              Mombeshora, Molly; Mukanganyama, Stanley  2019.0
# 2     Kimani, Njogu M.; Matasyoh, Josphat C.; Kaiser...  2017.0
# 3     Jan, Hasnain; Usman, Hazrat; Shah, Muzamil; Za...  2021.0
# 4     Panda, Sujogya Kumar; Castro, Ana Hortência Fo...  2020.0
# ...                                                 ...     ...
# 8246  Wang, Qiuming; Yu, Xiang; Patal, Kunal; Hu, Ru...  2013.0
# 8247  Zhang, Jin-qiang; Wu, Xiao-hui; Feng, Yi; Xie,...  2016.0
# 8248  Qi, Kang; Li, Lujin; Li, Xiangdong; Zhao, Jing...  2015.0
# 8249  Li, Xiao-Bing; Wang, Wei; Zhou, Guo-Jun; Li, Y...  2012.0
# 8250  Zhang, Mingxu; Yang, Jiawei; Zhao, Xiulan; Zha...  2021.0
#
#                                                Abstract  \
# 0     About half of the world’s population and 80% o...
# 1     Background: Pseudomonas aeruginosa has become ...
# 2     Sleeping sickness or human African trypanosomi...
# 3     Background: Himalayan Columbine (Aquilegia pub...
# 4     Chikungunya and yellow fever virus cause vecto...
# ...                                                 ...
# 8246  The misfolding and aggregation of amyloid-β (A...
# 8247  Aim:: Major depressive disorder (MDD) is a deb...
# 8248  Objective: Tongxinluo (TXL) has been shown to ...
# 8249  Drying is the most common and fundamental proc...
# 8250  Diabetic retinopathy (DR) is a leading cause o...
#
#                          Paper_type
# 0     ['Journal Article', 'Review']
# 1               ['Journal Article']
# 2               ['Journal Article']
# 3               ['Journal Article']
# 4               ['Journal Article']
# ...                             ...
# 8246            ['Journal Article']
# 8247            ['Journal Article']
# 8248            ['Journal Article']
# 8249            ['Journal Article']
# 8250            ['Journal Article']
#
# [8251 rows x 6 columns]

# %% [markdown]
# Screening

# %%
table_1_with_PT = df.drop(df[df["Paper_type"] == "NaN"].index)
table_1_with_PT.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8251 entries, 0 to 8250
# Data columns (total 6 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Journal     8251 non-null   object
#  1   Title       8251 non-null   object
#  2   Authors     8251 non-null   object
#  3   Year        8022 non-null   float64
#  4   Abstract    8198 non-null   object
#  5   Paper_type  8251 non-null   object
# dtypes: float64(1), object(5)
# memory usage: 386.9+ KB

# %%
#drop records without Paper type
table_1_with_PT = df.drop(df[df["Paper_type"] == "No paper type"].index)
table_1_with_PT
# Out:
#                                                 Journal  \
# 0                         Clinical Microbiology Reviews
# 1            BMC Complementary and Alternative Medicine
# 2     Molecules : A Journal of Synthetic Chemistry a...
# 3              BMC Complementary Medicine and Therapies
# 4                                               Viruses
# ...                                                 ...
# 8246                          ACS Chemical Neuroscience
# 8247                         Acta Pharmacologica Sinica
# 8248                                           PLoS ONE
# 8249                                          Molecules
# 8250                                 Scientific Reports
#
#                                                   Title  \
# 0     Natural-Product-Based Solutions for Tropical I...
# 1     Antibacterial activities, proposed mode of act...
# 2     Anti-Trypanosomatid Elemanolide Sesquiterpene ...
# 3     Phytochemical analysis and versatile in vitro ...
# 4     Antiviral and Cytotoxic Activity of Different ...
# ...                                                 ...
# 8246  Tanshinones Inhibit Amyloid Aggregation by Amy...
# 8247  Salvianolic acid B ameliorates depressive-like...
# 8248  Cardiac Microvascular Barrier Function Mediate...
# 8249  Production of Salvianolic Acid B in Roots of S...
# 8250  Network pharmacology and molecular docking stu...
#
#                                                 Authors    Year  \
# 0     Adegboye, Oyelola; Field, Matt A.; Kupz, Andre...     NaN
# 1              Mombeshora, Molly; Mukanganyama, Stanley  2019.0
# 2     Kimani, Njogu M.; Matasyoh, Josphat C.; Kaiser...  2017.0
# 3     Jan, Hasnain; Usman, Hazrat; Shah, Muzamil; Za...  2021.0
# 4     Panda, Sujogya Kumar; Castro, Ana Hortência Fo...  2020.0
# ...                                                 ...     ...
# 8246  Wang, Qiuming; Yu, Xiang; Patal, Kunal; Hu, Ru...  2013.0
# 8247  Zhang, Jin-qiang; Wu, Xiao-hui; Feng, Yi; Xie,...  2016.0
# 8248  Qi, Kang; Li, Lujin; Li, Xiangdong; Zhao, Jing...  2015.0
# 8249  Li, Xiao-Bing; Wang, Wei; Zhou, Guo-Jun; Li, Y...  2012.0
# 8250  Zhang, Mingxu; Yang, Jiawei; Zhao, Xiulan; Zha...  2021.0
#
#                                                Abstract  \
# 0     About half of the world’s population and 80% o...
# 1     Background: Pseudomonas aeruginosa has become ...
# 2     Sleeping sickness or human African trypanosomi...
# 3     Background: Himalayan Columbine (Aquilegia pub...
# 4     Chikungunya and yellow fever virus cause vecto...
# ...                                                 ...
# 8246  The misfolding and aggregation of amyloid-β (A...
# 8247  Aim:: Major depressive disorder (MDD) is a deb...
# 8248  Objective: Tongxinluo (TXL) has been shown to ...
# 8249  Drying is the most common and fundamental proc...
# 8250  Diabetic retinopathy (DR) is a leading cause o...
#
#                          Paper_type
# 0     ['Journal Article', 'Review']
# 1               ['Journal Article']
# 2               ['Journal Article']
# 3               ['Journal Article']
# 4               ['Journal Article']
# ...                             ...
# 8246            ['Journal Article']
# 8247            ['Journal Article']
# 8248            ['Journal Article']
# 8249            ['Journal Article']
# 8250            ['Journal Article']
#
# [8251 rows x 6 columns]

# %%
table_1_with_PT.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8251 entries, 0 to 8250
# Data columns (total 6 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Journal     8251 non-null   object
#  1   Title       8251 non-null   object
#  2   Authors     8251 non-null   object
#  3   Year        8022 non-null   float64
#  4   Abstract    8198 non-null   object
#  5   Paper_type  8251 non-null   object
# dtypes: float64(1), object(5)
# memory usage: 386.9+ KB

# %%
#drop records with Paper type: Review and co
table_1_filter = table_1_with_PT.drop(table_1_with_PT[table_1_with_PT["Paper_type"] == "['Journal Article', 'Review']"].index)
table_1_filter.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 5793 entries, 1 to 8250
# Data columns (total 6 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Journal     5793 non-null   object
#  1   Title       5793 non-null   object
#  2   Authors     5793 non-null   object
#  3   Year        5630 non-null   float64
#  4   Abstract    5761 non-null   object
#  5   Paper_type  5793 non-null   object
# dtypes: float64(1), object(5)
# memory usage: 316.8+ KB

# %%
table_1_filter = table_1_filter.drop(table_1_filter[table_1_filter["Paper_type"] == "['Journal Article', 'News']"].index)
table_1_filter.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 5760 entries, 1 to 8250
# Data columns (total 6 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Journal     5760 non-null   object
#  1   Title       5760 non-null   object
#  2   Authors     5760 non-null   object
#  3   Year        5598 non-null   float64
#  4   Abstract    5728 non-null   object
#  5   Paper_type  5760 non-null   object
# dtypes: float64(1), object(5)
# memory usage: 315.0+ KB

# %%
table_1_filter = table_1_filter.drop(table_1_filter[table_1_filter["Paper_type"] == "['Journal Article', 'Editorial']"].index)
table_1_filter.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 5706 entries, 1 to 8250
# Data columns (total 6 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Journal     5706 non-null   object
#  1   Title       5706 non-null   object
#  2   Authors     5706 non-null   object
#  3   Year        5545 non-null   float64
#  4   Abstract    5674 non-null   object
#  5   Paper_type  5706 non-null   object
# dtypes: float64(1), object(5)
# memory usage: 312.0+ KB

# %%
table_1_filter = table_1_filter.drop(table_1_filter[table_1_filter["Paper_type"] == "['Journal Article', 'Published Erratum']"].index)
table_1_filter.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 5706 entries, 1 to 8250
# Data columns (total 6 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Journal     5706 non-null   object
#  1   Title       5706 non-null   object
#  2   Authors     5706 non-null   object
#  3   Year        5545 non-null   float64
#  4   Abstract    5674 non-null   object
#  5   Paper_type  5706 non-null   object
# dtypes: float64(1), object(5)
# memory usage: 312.0+ KB

# %%
table_1_filter = table_1_filter.drop(table_1_filter[table_1_filter["Paper_type"] == "['Journal Article', 'Case Report']"].index)
table_1_filter.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 5692 entries, 1 to 8250
# Data columns (total 6 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Journal     5692 non-null   object
#  1   Title       5692 non-null   object
#  2   Authors     5692 non-null   object
#  3   Year        5531 non-null   float64
#  4   Abstract    5660 non-null   object
#  5   Paper_type  5692 non-null   object
# dtypes: float64(1), object(5)
# memory usage: 311.3+ KB

# %%
table_1_filter = table_1_filter.drop(table_1_filter[table_1_filter["Paper_type"] == "['Journal Article', 'Journal Article', 'Review']"].index)
table_1_filter.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 5692 entries, 1 to 8250
# Data columns (total 6 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Journal     5692 non-null   object
#  1   Title       5692 non-null   object
#  2   Authors     5692 non-null   object
#  3   Year        5531 non-null   float64
#  4   Abstract    5660 non-null   object
#  5   Paper_type  5692 non-null   object
# dtypes: float64(1), object(5)
# memory usage: 311.3+ KB

# %%
table_1_filter = table_1_filter.drop(table_1_filter[table_1_filter["Paper_type"] == "['Journal Article', 'Letter']"].index)
table_1_filter.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 5678 entries, 1 to 8250
# Data columns (total 6 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Journal     5678 non-null   object
#  1   Title       5678 non-null   object
#  2   Authors     5678 non-null   object
#  3   Year        5517 non-null   float64
#  4   Abstract    5646 non-null   object
#  5   Paper_type  5678 non-null   object
# dtypes: float64(1), object(5)
# memory usage: 310.5+ KB

# %%
table_1_filter = table_1_filter.drop(table_1_filter[table_1_filter["Paper_type"] == "['Journal Article', 'Comment']"].index)
table_1_filter.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 5662 entries, 1 to 8250
# Data columns (total 6 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Journal     5662 non-null   object
#  1   Title       5662 non-null   object
#  2   Authors     5662 non-null   object
#  3   Year        5501 non-null   float64
#  4   Abstract    5630 non-null   object
#  5   Paper_type  5662 non-null   object
# dtypes: float64(1), object(5)
# memory usage: 309.6+ KB

# %%
table_1_filter
# Out:
#                                                 Journal  \
# 1            BMC Complementary and Alternative Medicine
# 2     Molecules : A Journal of Synthetic Chemistry a...
# 3              BMC Complementary Medicine and Therapies
# 4                                               Viruses
# 5                                             Molecules
# ...                                                 ...
# 8246                          ACS Chemical Neuroscience
# 8247                         Acta Pharmacologica Sinica
# 8248                                           PLoS ONE
# 8249                                          Molecules
# 8250                                 Scientific Reports
#
#                                                   Title  \
# 1     Antibacterial activities, proposed mode of act...
# 2     Anti-Trypanosomatid Elemanolide Sesquiterpene ...
# 3     Phytochemical analysis and versatile in vitro ...
# 4     Antiviral and Cytotoxic Activity of Different ...
# 5     Antiprotozoal Activity of Plants Used in the M...
# ...                                                 ...
# 8246  Tanshinones Inhibit Amyloid Aggregation by Amy...
# 8247  Salvianolic acid B ameliorates depressive-like...
# 8248  Cardiac Microvascular Barrier Function Mediate...
# 8249  Production of Salvianolic Acid B in Roots of S...
# 8250  Network pharmacology and molecular docking stu...
#
#                                                 Authors    Year  \
# 1              Mombeshora, Molly; Mukanganyama, Stanley  2019.0
# 2     Kimani, Njogu M.; Matasyoh, Josphat C.; Kaiser...  2017.0
# 3     Jan, Hasnain; Usman, Hazrat; Shah, Muzamil; Za...  2021.0
# 4     Panda, Sujogya Kumar; Castro, Ana Hortência Fo...  2020.0
# 5     Vahekeni, Nina; Brillatz, Théo; Rahmaty, Marja...  2024.0
# ...                                                 ...     ...
# 8246  Wang, Qiuming; Yu, Xiang; Patal, Kunal; Hu, Ru...  2013.0
# 8247  Zhang, Jin-qiang; Wu, Xiao-hui; Feng, Yi; Xie,...  2016.0
# 8248  Qi, Kang; Li, Lujin; Li, Xiangdong; Zhao, Jing...  2015.0
# 8249  Li, Xiao-Bing; Wang, Wei; Zhou, Guo-Jun; Li, Y...  2012.0
# 8250  Zhang, Mingxu; Yang, Jiawei; Zhao, Xiulan; Zha...  2021.0
#
#                                                Abstract           Paper_type
# 1     Background: Pseudomonas aeruginosa has become ...  ['Journal Article']
# 2     Sleeping sickness or human African trypanosomi...  ['Journal Article']
# 3     Background: Himalayan Columbine (Aquilegia pub...  ['Journal Article']
# 4     Chikungunya and yellow fever virus cause vecto...  ['Journal Article']
# 5     Folk medicine is widely used in Angola, even f...  ['Journal Article']
# ...                                                 ...                  ...
# 8246  The misfolding and aggregation of amyloid-β (A...  ['Journal Article']
# 8247  Aim:: Major depressive disorder (MDD) is a deb...  ['Journal Article']
# 8248  Objective: Tongxinluo (TXL) has been shown to ...  ['Journal Article']
# 8249  Drying is the most common and fundamental proc...  ['Journal Article']
# 8250  Diabetic retinopathy (DR) is a leading cause o...  ['Journal Article']
#
# [5662 rows x 6 columns]

# %%
table_1_filter[table_1_filter["Abstract"] == "NaN"]
table_1_filter
# Out:
#                                                 Journal  \
# 1            BMC Complementary and Alternative Medicine
# 2     Molecules : A Journal of Synthetic Chemistry a...
# 3              BMC Complementary Medicine and Therapies
# 4                                               Viruses
# 5                                             Molecules
# ...                                                 ...
# 8246                          ACS Chemical Neuroscience
# 8247                         Acta Pharmacologica Sinica
# 8248                                           PLoS ONE
# 8249                                          Molecules
# 8250                                 Scientific Reports
#
#                                                   Title  \
# 1     Antibacterial activities, proposed mode of act...
# 2     Anti-Trypanosomatid Elemanolide Sesquiterpene ...
# 3     Phytochemical analysis and versatile in vitro ...
# 4     Antiviral and Cytotoxic Activity of Different ...
# 5     Antiprotozoal Activity of Plants Used in the M...
# ...                                                 ...
# 8246  Tanshinones Inhibit Amyloid Aggregation by Amy...
# 8247  Salvianolic acid B ameliorates depressive-like...
# 8248  Cardiac Microvascular Barrier Function Mediate...
# 8249  Production of Salvianolic Acid B in Roots of S...
# 8250  Network pharmacology and molecular docking stu...
#
#                                                 Authors    Year  \
# 1              Mombeshora, Molly; Mukanganyama, Stanley  2019.0
# 2     Kimani, Njogu M.; Matasyoh, Josphat C.; Kaiser...  2017.0
# 3     Jan, Hasnain; Usman, Hazrat; Shah, Muzamil; Za...  2021.0
# 4     Panda, Sujogya Kumar; Castro, Ana Hortência Fo...  2020.0
# 5     Vahekeni, Nina; Brillatz, Théo; Rahmaty, Marja...  2024.0
# ...                                                 ...     ...
# 8246  Wang, Qiuming; Yu, Xiang; Patal, Kunal; Hu, Ru...  2013.0
# 8247  Zhang, Jin-qiang; Wu, Xiao-hui; Feng, Yi; Xie,...  2016.0
# 8248  Qi, Kang; Li, Lujin; Li, Xiangdong; Zhao, Jing...  2015.0
# 8249  Li, Xiao-Bing; Wang, Wei; Zhou, Guo-Jun; Li, Y...  2012.0
# 8250  Zhang, Mingxu; Yang, Jiawei; Zhao, Xiulan; Zha...  2021.0
#
#                                                Abstract           Paper_type
# 1     Background: Pseudomonas aeruginosa has become ...  ['Journal Article']
# 2     Sleeping sickness or human African trypanosomi...  ['Journal Article']
# 3     Background: Himalayan Columbine (Aquilegia pub...  ['Journal Article']
# 4     Chikungunya and yellow fever virus cause vecto...  ['Journal Article']
# 5     Folk medicine is widely used in Angola, even f...  ['Journal Article']
# ...                                                 ...                  ...
# 8246  The misfolding and aggregation of amyloid-β (A...  ['Journal Article']
# 8247  Aim:: Major depressive disorder (MDD) is a deb...  ['Journal Article']
# 8248  Objective: Tongxinluo (TXL) has been shown to ...  ['Journal Article']
# 8249  Drying is the most common and fundamental proc...  ['Journal Article']
# 8250  Diabetic retinopathy (DR) is a leading cause o...  ['Journal Article']
#
# [5662 rows x 6 columns]

# %%
#detect records without abstract
table_1_filter[table_1_filter["Abstract"] == "No abstract"]
# Out:
#                                           Journal  \
# 67                                  FEBS Open Bio
# 188                              Journal of Fungi
# 419                                 FEBS Open Bio
# 740             Journal of Extracellular Vesicles
# 857                                  VirusDisease
# ...                                           ...
# 8159                   London journal of medicine
# 8163                      British Medical Journal
# 8165                  Medical History. Supplement
# 8178  Journal of the National Medical Association
# 8218                   Acta Pharmacologica Sinica
#
#                                                   Title  \
# 67                                             Posters.
# 188   9th Trends in Medical Mycology Held on 11–14 O...
# 419                                            Posters.
# 740                             ISEV2024 Abstract Book.
# 857   Abstracts of the papers presented in the inter...
# ...                                                 ...
# 8159                            Digest of the Journals.
# 8163                       The British Medical Journal.
# 8165  Animism, vitalism, and the Medical University ...
# 8178  Social service aspects of drug addiction in th...
# 8218  The challenges and opportunities of traditiona...
#
#                                                 Authors    Year     Abstract  \
# 67                                           No authors  2024.0  No abstract
# 188   Gangneux, Jean-Pierre; Lortholary, Olivier; Co...  2019.0  No abstract
# 419                                          No authors  2023.0  No abstract
# 740                                          No authors  2024.0  No abstract
# 857                                          No authors  2023.0  No abstract
# ...                                                 ...     ...          ...
# 8159                                         No authors  1852.0  No abstract
# 8163                                         No authors  1887.0  No abstract
# 8165                                         No authors  1984.0  No abstract
# 8178                                       Beine, E. C.  1974.0  No abstract
# 8218  Zuo, Hua-li; Lin, Yang-Chi-Dung; Huang, Hsi-Yu...  2021.0  No abstract
#
#                Paper_type
# 67    ['Journal Article']
# 188   ['Journal Article']
# 419   ['Journal Article']
# 740   ['Journal Article']
# 857   ['Journal Article']
# ...                   ...
# 8159  ['Journal Article']
# 8163  ['Journal Article']
# 8165  ['Journal Article']
# 8178  ['Journal Article']
# 8218  ['Journal Article']
#
# [567 rows x 6 columns]

# %%
#drop records without abstracts
table_1_with_abstracts = table_1_filter.drop(table_1_filter[table_1_filter["Abstract"] == "No abstract"].index)
table_1_with_abstracts.to_csv("table_1_with_abstracts.csv", index=False)
table_1_with_abstracts.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 5095 entries, 1 to 8250
# Data columns (total 6 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Journal     5095 non-null   object
#  1   Title       5095 non-null   object
#  2   Authors     5095 non-null   object
#  3   Year        4937 non-null   float64
#  4   Abstract    5063 non-null   object
#  5   Paper_type  5095 non-null   object
# dtypes: float64(1), object(5)
# memory usage: 278.6+ KB

# %%
#drop records without abstracts
table_1_with_abstracts = table_1_with_abstracts.drop(table_1_with_abstracts[table_1_with_abstracts["Abstract"] == "NaN"].index)
table_1_with_abstracts.to_csv("table_1_with_abstracts.csv", index=False)
table_1_with_abstracts.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 5095 entries, 1 to 8250
# Data columns (total 6 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Journal     5095 non-null   object
#  1   Title       5095 non-null   object
#  2   Authors     5095 non-null   object
#  3   Year        4937 non-null   float64
#  4   Abstract    5063 non-null   object
#  5   Paper_type  5095 non-null   object
# dtypes: float64(1), object(5)
# memory usage: 278.6+ KB

# %%
table_1_with_abstracts
# Out:
#                                                 Journal  \
# 1            BMC Complementary and Alternative Medicine
# 2     Molecules : A Journal of Synthetic Chemistry a...
# 3              BMC Complementary Medicine and Therapies
# 4                                               Viruses
# 5                                             Molecules
# ...                                                 ...
# 8246                          ACS Chemical Neuroscience
# 8247                         Acta Pharmacologica Sinica
# 8248                                           PLoS ONE
# 8249                                          Molecules
# 8250                                 Scientific Reports
#
#                                                   Title  \
# 1     Antibacterial activities, proposed mode of act...
# 2     Anti-Trypanosomatid Elemanolide Sesquiterpene ...
# 3     Phytochemical analysis and versatile in vitro ...
# 4     Antiviral and Cytotoxic Activity of Different ...
# 5     Antiprotozoal Activity of Plants Used in the M...
# ...                                                 ...
# 8246  Tanshinones Inhibit Amyloid Aggregation by Amy...
# 8247  Salvianolic acid B ameliorates depressive-like...
# 8248  Cardiac Microvascular Barrier Function Mediate...
# 8249  Production of Salvianolic Acid B in Roots of S...
# 8250  Network pharmacology and molecular docking stu...
#
#                                                 Authors    Year  \
# 1              Mombeshora, Molly; Mukanganyama, Stanley  2019.0
# 2     Kimani, Njogu M.; Matasyoh, Josphat C.; Kaiser...  2017.0
# 3     Jan, Hasnain; Usman, Hazrat; Shah, Muzamil; Za...  2021.0
# 4     Panda, Sujogya Kumar; Castro, Ana Hortência Fo...  2020.0
# 5     Vahekeni, Nina; Brillatz, Théo; Rahmaty, Marja...  2024.0
# ...                                                 ...     ...
# 8246  Wang, Qiuming; Yu, Xiang; Patal, Kunal; Hu, Ru...  2013.0
# 8247  Zhang, Jin-qiang; Wu, Xiao-hui; Feng, Yi; Xie,...  2016.0
# 8248  Qi, Kang; Li, Lujin; Li, Xiangdong; Zhao, Jing...  2015.0
# 8249  Li, Xiao-Bing; Wang, Wei; Zhou, Guo-Jun; Li, Y...  2012.0
# 8250  Zhang, Mingxu; Yang, Jiawei; Zhao, Xiulan; Zha...  2021.0
#
#                                                Abstract           Paper_type
# 1     Background: Pseudomonas aeruginosa has become ...  ['Journal Article']
# 2     Sleeping sickness or human African trypanosomi...  ['Journal Article']
# 3     Background: Himalayan Columbine (Aquilegia pub...  ['Journal Article']
# 4     Chikungunya and yellow fever virus cause vecto...  ['Journal Article']
# 5     Folk medicine is widely used in Angola, even f...  ['Journal Article']
# ...                                                 ...                  ...
# 8246  The misfolding and aggregation of amyloid-β (A...  ['Journal Article']
# 8247  Aim:: Major depressive disorder (MDD) is a deb...  ['Journal Article']
# 8248  Objective: Tongxinluo (TXL) has been shown to ...  ['Journal Article']
# 8249  Drying is the most common and fundamental proc...  ['Journal Article']
# 8250  Diabetic retinopathy (DR) is a leading cause o...  ['Journal Article']
#
# [5095 rows x 6 columns]
