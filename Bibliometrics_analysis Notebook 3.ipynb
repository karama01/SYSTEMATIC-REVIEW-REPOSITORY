# %% [markdown]
# Journal and author numbers

# %%
import pandas as pd
import seaborn as sns

# %%
papers = pd.read_csv("/content/2_eligible_publications.csv", sep=",", encoding='latin-1')
papers
# Out:
#                                       Journal  \
# 0            Journal of Parasitology Research
# 1                                Marine Drugs
# 2                                Marine Drugs
# 3                                Marine Drugs
# 4                                Marine Drugs
# ..                                        ...
# 672             BioMed Research International
# 673                        Scientific Reports
# 674  BMC Complementary Medicine and Therapies
# 675                             Pharmaceutics
# 676                             Pharmaceutics
#
#                                                  Title Tag1           Tag2  \
# 0    Larvicidal Activity against Aedes aegypti and ...   1C          Algae
# 1    Biological Activities and Chemical Composition...   1A          Algae
# 2    The Brown Alga Stypopodium zonale (Dictyotacea...   1A          Algae
# 3    Potential Utilization of a Polysaccharide from...   1D          Algae
# ...

# %%
print(papers.columns)
# Out:
# Index(['Journal', 'Title', 'Tag1', 'Tag2', 'Authors', 'Year', 'Abstract',
#        'Paper_type', 'Affiliation'],
#       dtype='object')

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Load the CSV file
file_path = '/content/2_eligible_publications.csv'
data = pd.read_csv(file_path, encoding='ISO-8859-1')

# Define the mapping for Tag1 labels
tag1_labels = {
    "1A": "Antiparasitic",
    "1B": "Antiviral",
    "1C": "Anti-vector",
    "1D": "Antiophidian",
    "1E": "Antifungal",
    "1F": "Antibacterial",
}

# Map the Tag1 codes to their descriptions
data['Tag1_Label'] = data['Tag1'].map(tag1_labels)

# Count the number of papers for each Tag1 label
paper_counts = data['Tag1_Label'].value_counts()

# Plot the results
plt.figure(figsize=(10, 6), dpi=300)
paper_counts.plot(kind='bar', color='skyblue', edgecolor='black')
#plt.title('Paper Counts by Tag1 Labels', fontsize=16)
plt.xlabel('Anti-NTD activities of Natural products', fontsize=14)
plt.ylabel('Number of Papers', fontsize=14)
plt.xticks(rotation=45, ha='right', fontsize=12)
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.tight_layout()

# Show the plot
plt.show()

# %%
# prompt: Generate a table showing the numbers of papers per tag and save to csv

import pandas as pd

# Load the CSV file
file_path = '/content/2_eligible_publications.csv'
data = pd.read_csv(file_path, encoding='ISO-8859-1')

# Define the mapping for Tag1 labels
tag1_labels = {
    "1A": "Antiparasitic",
    "1B": "Antiviral",
    "1C": "Anti-vector",
    "1D": "Antiophidian",
    "1E": "Antifungal",
    "1F": "Antibacterial",
}

# Map the Tag1 codes to their descriptions
data['Tag1_Label'] = data['Tag1'].map(tag1_labels)

# Count the number of papers for each Tag1 label
paper_counts = data['Tag1_Label'].value_counts()

# Create a DataFrame from the paper counts
paper_counts_df = pd.DataFrame({'Tag1_Label': paper_counts.index, 'Number of Papers': paper_counts.values})

# Save the DataFrame to a CSV file
paper_counts_df.to_csv('paper_counts_by_tag.csv', index=False)

print("Paper counts saved to 'paper_counts_by_tag.csv'")
# Out:
# Paper counts saved to 'paper_counts_by_tag.csv'

# %%
paper_counts_df
# Out:
#       Tag1_Label  Number of Papers
# 0  Antiparasitic               545
# 1    Anti-vector                52
# 2   Antiophidian                42
# 3      Antiviral                19
# 4     Antifungal                11
# 5  Antibacterial                 7

# %%
plt.figure(figsize=(5.5, 5.5))

sns.countplot(x='Tag2', data=papers, edgecolor='black')

plt.xlabel('Bioactivity class of Natural product', fontsize=14)
plt.ylabel('Number of Articles', fontsize=14)
plt.xticks(rotation=45, ha='right', fontsize=12)
plt.rcParams['figure.dpi'] = 300
plt.rcParams["font.family"] = "Arial"

#plt.savefig('plot_bioactivity_class.png')
# Out:
# WARNING:matplotlib.font_manager:findfont: Font family 'Arial' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Arial' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Arial' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Arial' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Arial' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Arial' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Arial' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Arial' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Arial' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Arial' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Arial' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Arial' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Arial' not found.
# ...

# %%
# prompt: Generate a table for the bioactivity chart (Tag5) so I can see the figures numerically

import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# Load the CSV file
file_path = '/content/2_eligible_publications.csv'
data = pd.read_csv(file_path, encoding='ISO-8859-1')

# Count the number of papers for each Tag5 label
tag5_counts = data['Tag2'].value_counts()

# Create a DataFrame from the Tag5 counts
tag5_counts_df = pd.DataFrame({'Tag5_Label': tag5_counts.index, 'Number of Papers': tag5_counts.values})

tag5_counts_df.to_csv('tag5_counts_df', index=False)

# Display the table
tag5_counts_df
# Out:
#           Tag5_Label  Number of Papers
# 0     Plant compound               254
# 1      Plant extract               252
# 2      Essential oil                81
# 3  Microbial-derived                50
# 4     Animal-derived                16
# 5              Algae                12
# 6     Marine-derived                10
# 7              Other                 2

# %%
# prompt: A boxplot of Tag 5 by Year with dpi = 300

import matplotlib.pyplot as plt
import seaborn as sns

plt.figure(figsize=(8, 6), dpi=300)  # Adjust figure size and DPI
sns.boxplot(x='Year', y='Tag2', data=papers)
plt.xlabel('Year', fontsize=12)
plt.ylabel('Bioactivity class', fontsize=12)
#plt.title('Boxplot of Tag 5 by Year', fontsize=14)
plt.xticks(rotation=45, ha='right')  # Rotate x-axis labels for better readability
plt.tight_layout()
plt.show()
# Out:
# WARNING:matplotlib.font_manager:findfont: Font family 'Arial' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Arial' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Arial' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Arial' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Arial' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Arial' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Arial' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Arial' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Arial' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Arial' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Arial' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Arial' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Arial' not found.
# ...

# %%
# prompt: I want the year range for the boxplot to be 2000 - 2024

plt.figure(figsize=(8, 6), dpi=300)  # Adjust figure size and DPI
sns.boxplot(x='Year', y='Tag2', data=papers[papers['Year'].between(2000, 2024)])
plt.xlabel('Year', fontsize=12)
plt.ylabel('Bioactivity class', fontsize=12)
#plt.title('Boxplot of Tag 5 by Year', fontsize=14)
plt.xticks(rotation=45, ha='right')  # Rotate x-axis labels for better readability
plt.tight_layout()
plt.show()
# Out:
# WARNING:matplotlib.font_manager:findfont: Font family 'Arial' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Arial' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Arial' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Arial' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Arial' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Arial' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Arial' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Arial' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Arial' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Arial' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Arial' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Arial' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Arial' not found.
# ...

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

plt.figure(figsize=(8, 6), dpi=300)  # Adjust figure size and DPI
ax = sns.boxplot(x='Year', y='Tag2', data=papers)

# Set x-axis labels to integers only
years = sorted(papers["Year"].unique())  # Get unique years
plt.xticks(ticks=np.arange(min(years), max(years) + 1, 2), labels=np.arange(min(years), max(years) + 1, 2), rotation=45, ha='right')

plt.xlabel('Year', fontsize=12)
plt.ylabel('Bioactivity class', fontsize=12)
plt.tight_layout()
plt.show()
