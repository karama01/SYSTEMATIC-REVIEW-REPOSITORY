# %% [markdown]
# WORD CLOUD FROM TITLES

# %%
import pandas as pd
from wordcloud import WordCloud

# Download NLTK stopwords
nltk.download('stopwords')

# %%
data = pd.read_csv("/content/4_updated_subset_with_affiliation.csv")
data
# Out:
#                                                Journal  \
# 0    Molecules : A Journal of Synthetic Chemistry a...
# 1                                              Viruses
# 2                                            Molecules
# 3                                            Molecules
# 4                                               Plants
# ..                                                 ...
# 560                                        Scientifica
# 561                   PLoS Neglected Tropical Diseases
# 562  The Journal of Venomous Animals and Toxins Inc...
# 563                                            Viruses
# 564  Interdisciplinary Perspectives on Infectious D...
#
#                                                  Title Tag1 Tag2 Tag3 Tag4  \
# 0    Anti-Trypanosomatid Elemanolide Sesquiterpene ...   1A  2AA  NaN  NaN
# 1    Antiviral and Cytotoxic Activity of Different ...   1B  2BB  NaN  NaN
# 2    Antiprotozoal Activity of Plants Used in the M...   1A  2AA  NaN  NaN
# ...

# %%
# Ensure the 'Title' column exists
if 'Title' not in data.columns:
    raise ValueError("The dataset does not have a 'Title' column.")

# Combine all titles into a single text string
text = " ".join(str(title) for title in data['Title'].dropna())

# %%
# Preprocess the text: remove non-alphanumeric characters and lower the text
text = re.sub(r'\W+,', ' ', text).lower()

# %%
# Remove stopwords
stop_words = set(stopwords.word('english'))
filtered_words = [word for word in text.split() if word not in stop_word]

# %%
# Generate a word cloud
wordcloud = WordCloud(
    width=2000,
    height=1000,
    background_color='white',
    stopwords=stop_words,
    max_words=200,
    colormap='viridis'
).generate(" ".join(filtered_words))

# Plot the word cloud
plt.figure(figsize=(16, 6))
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis('off')
plt.show()
# Out:
# Output hidden; open in https://colab.research.google.com to view.
